# %% [markdown]
# <a href="https://colab.research.google.com/github/Shahbaz894/100-days-of-machine-learning/blob/main/redge_regression_from_scratch_by_shahbaz.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from sklearn.datasets import make_regression
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# # Ridge Regression
# Ridge regression is a type of regularized regression model. This means it is a variation of the standard linear regression model that includes a regularized term in the cost function. The purpose of this is to prevent Overfitting. Ridge Regression adds an L2 regularization term to the linear equation. That’s why it is also known as L2 Regularization or L2 Norm.
#
# T**he main aim of Ridge Regression is to reduce Overfitting.**
#
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# When you fit a Linear Regression model, here is what happens. You have a set of features (often called X and represented as a matrix) and you want to find a set of coefficients (often called β and represented as a vector) by which you multiply the values in X to predict your target (often called y and represented as a vector)
#
#
# ![image.png](data:image/png;base64,...)
#
# The problem is that, in some cases, a Linear Regression will overfit specific datasets. What do you do in this case? Use Ridge and Lasso regression.
#
# How do these models work?
# Lasso and Ridge are both Linear Regression models but with a penalty (also called a regularization). They add a penalty to how big your beta vector can get, each in a different way.

# %% [markdown]
# ![WhatsApp Image 2023-07-12 at 11.16.32 AM.jpeg](data:image/jpeg;base64,...)
# ![WhatsApp Image 2023-07-12 at 11.17.37 AM.jpeg](data:image/jpeg;base64,...)

# %% [markdown]
# ![WhatsApp Image 2023-07-12 at 11.20.08 AM.jpeg](data:image/jpeg;base64,...)
#
#
# ![WhatsApp Image 2023-07-12 at 11.20.11 AM.jpeg](data:image/jpeg;base64,...)
#
# ![WhatsApp Image 2023-07-12 at 11.20.12 AM.jpeg](data:image/jpeg;base64,...)
# ![WhatsApp Image 2023-07-12 at 11.20.12 AM (1).jpeg](data:image/jpeg;base64,...)
# ![WhatsApp Image 2023-07-12 at 11.20.12 AM (1).jpeg](data:image/jpeg;base64,...)
# ![WhatsApp Image 2023-07-12 at 11.20.22 AM.jpeg](data:image/jpeg;base64,...)
#
# ![WhatsApp Image 2023-07-12 at 11.20.26 AM.jpeg](data:image/jpeg;base64,...)
# ![WhatsApp Image 2023-07-12 at 11.20.31 AM.jpeg](data:image/jpeg;base64,...)
#
# ![WhatsApp Image 2023-07-12 at 11.20.46 AM.jpeg](data:image/jpeg;base64,...)

# %%
X,y = make_regression(n_samples=100, n_features=1, n_informative=1, n_targets=1,noise=20,random_state=13)

# %%
plt.scatter(X,y)

# %%
from sklearn.linear_model import LinearRegression

# %%
lr = LinearRegression()
lr.fit(X,y)
print(lr.coef_)
print(lr.intercept_)
# Out:
# [27.82809103]
# -2.29474455867698

# %% [markdown]
# # Applying regRegression

# %%
from sklearn.linear_model import Ridge
#if we inrease the value of alpha(lamda) it decrease the value of m
rr=Ridge(alpha=100)
rr.fit(X,y)
print(rr.coef_)
print(rr.intercept_)
# Out:
# [12.93442104]
# -1.4248441496033308

# %%
rr1 = Ridge(alpha=200)
rr1.fit(X,y)
print(rr1.coef_)
print(rr1.intercept_)
# Out:
# [8.42522025]
# -1.1614734954021684

# %%
plt.plot(X,y,'b.')
plt.plot(X,lr.predict(X),color='red',label='alpha=0')
plt.plot(X,rr.predict(X),color='green',label='alpha=10')
plt.plot(X,rr1.predict(X),color='orange',label='alpha=100')
plt.legend()

# %% [markdown]
# ## Make your own class for linear regression

# %%
def linear_regression(X,y,alpha=1):
  x_mean=X.mean()
  y_mean=y.mean()
  num=0
  den=0
  for i in range(X.shape[0]):
    num=num + (y[i] -y_mean) *(X[i] - x_mean)
    den=den + (X[i] -x_mean) *(X[i] - x_mean)
  m=num/(den+alpha )
  b=y_mean - m*x_mean
  return m,b

# %%
class MeraRidge:

    def __init__(self,alpha=0.1):
        self.alpha = alpha
        self.m = None
        self.b = None

    def fit(self,X_train,y_train):

        num = 0
        den = 0

        for i in range(X_train.shape[0]):
            num = num + (y_train[i] - y_train.mean())*(X_train[i] - X_train.mean())
            den = den + (X_train[i] - X_train.mean())*(X_train[i] - X_train.mean())

        self.m = num/(den + self.alpha)
        self.b = y_train.mean() - (self.m*X_train.mean())
        print(self.m,self.b)

    def predict(X_test):
        pass

# %%
reg = MeraRidge(alpha=100)

# %%
reg.fit(X,y)
# Out:
# [12.93442104] [-1.42484415]
